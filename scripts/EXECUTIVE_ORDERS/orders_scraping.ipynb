# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import json
import time
import os

# %%
# Load the CSV file. Assuming no header based on inspection.
# Columns mapping based on observation:
# 0: Citation, 1: Doc Number, 2: Start Page, 3: URL, 4: PDF URL
# 5: Type, 6: Subtype, 7: Pub Date, 8: Sign Date, 9: FR Page
# 10: Title, 11: Notes, 12: EO Number, 13: Internal ID

csv_path = "orders.csv"

try:
    # Attempt to read with no header
    df = pd.read_csv(csv_path, header=None)
    print(f"Loaded {len(df)} rows.")
    
    # Rename useful columns for clarity
    column_mapping = {
        0: 'citation',
        1: 'document_number',
        2: 'start_page',
        3: 'url',
        4: 'pdf_url',
        5: 'doc_type',
        6: 'doc_subtype',
        7: 'publication_date',
        8: 'signing_date',
        9: 'fr_page',
        10: 'title',
        11: 'notes',
        12: 'order_number',
        13: 'internal_id'
    }
    df.rename(columns=column_mapping, inplace=True)
    
    # Display first few rows to verify
    display(df.head())

except Exception as e:
    print(f"Error loading CSV: {e}")
# Out:
# Loaded 219 rows.
#       citation  document_number start_page  \
# 0     citation  document_number   end_page
# 1  90 FR 43895       2025-17509      43897
# 2  90 FR 19611       2025-08266      19614
# 3  90 FR 17519       2025-07368      17523
# 4  90 FR 17525       2025-07369      17527
#
#                                                  url  \
# 0                                           html_url
# 1  https://www.federalregister.gov/documents/2025...
# 2  https://www.federalregister.gov/documents/2025...
# 3  https://www.federalregister.gov/documents/2025...
# 4  https://www.federalregister.gov/documents/2025...
#
#                                              pdf_url               doc_type  \
# 0                                            pdf_url                   type
# 1  https://www.govinfo.gov/content/pkg/FR-2025-09...  Presidential Document
# 2  https://www.govinfo.gov/content/pkg/FR-2025-05...  Presidential Document
# 3  https://www.govinfo.gov/content/pkg/FR-2025-04...  Presidential Document
# 4  https://www.govinfo.gov/content/pkg/FR-2025-04...  Presidential Document
#
#        doc_subtype  publication_date  signing_date     fr_page  \
# 0          subtype  publication_date  signing_date  start_page
# 1  Executive Order        09/10/2025    2025-09-05       43895
# 2  Executive Order        05/08/2025    2025-05-05       19611
# 3  Executive Order        04/28/2025    2025-04-23       17519
# 4  Executive Order        04/28/2025    2025-04-23       17525
#
#                                                title  \
# 0                                              title
# 1  Strengthening Efforts To Protect U.S. National...
# 2  Improving the Safety and Security of Biologica...
# 3  Advancing Artificial Intelligence Education fo...
# 4  Preparing Americans for High-Paying Skilled Tr...
#
#                            notes            order_number  \
# 0              disposition_notes  executive_order_number
# 1  See: EO 11295, August 5, 1966                   14348
# 2                            NaN                   14292
# 3                            NaN                   14277
# 4    See: EO 14302, May 23, 2025                   14278
#
#                     internal_id
# 0  not_received_for_publication
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN

# %%
def scrape_federal_register(url):
    """
    Fetches the Federal Register page and extracts the full text of the executive order.
    """
    try:
        headers = {
            "User-Agent": "LegalAI-Scraper/1.0 (Educational Purpose)"
        }
        response = requests.get(url, headers=headers, timeout=15)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Federal Register usually holds the document text in specific sections
        # Common identifiers for content:
        # - div class="full-text"
        # - div id="fulltext_content_area"
        # - div class="document-content"
        
        # Attempt to find the main content container
        content_div = soup.find('div', class_='full-text') or \
                      soup.find('div', id='fulltext_content_area') or \
                      soup.find('div', class_='document-content')
        
        if content_div:
            # Extract text, preserving some structure with newlines
            full_text = content_div.get_text(separator='\n\n', strip=True)
            return full_text
        else:
            # Fallback: Body text (messy but better than nothing)
            return soup.body.get_text(separator='\n\n', strip=True)
            
    except Exception as e:
        print(f"Error scraping {url}: {e}")
        return None

# %%
orders_data = []

# Rate limiting: Sleep between requests
SLEEP_SEC = 1

print("Starting scraping...")
for index, row in df.iterrows():
    url = row.get('url')
    title = row.get('title', f"Order {index}")
    
    if not url or not isinstance(url, str) or not url.startswith("http"):
        print(f"Skipping invalid URL at index {index}")
        continue
        
    print(f"Scraping [{index+1}/{len(df)}]: {title[:50]}...")
    
    full_text = scrape_federal_register(url)
    
    # construct record
    record = row.to_dict()
    record['full_text'] = full_text
    
    if not full_text:
        print("  -> No text found.")
        
    orders_data.append(record)
    
    time.sleep(SLEEP_SEC)
# Out:
# Starting scraping...
# Skipping invalid URL at index 0
# Scraping [2/219]: Strengthening Efforts To Protect U.S. Nationals Fr...
# Scraping [3/219]: Improving the Safety and Security of Biological Re...
# Scraping [4/219]: Advancing Artificial Intelligence Education for Am...
# Scraping [5/219]: Preparing Americans for High-Paying Skilled Trade ...
# Scraping [6/219]: Restoring Equality of Opportunity and Meritocracy...
# Scraping [7/219]: Transparency Regarding Foreign Influence at Americ...
# Scraping [8/219]: White House Initiative To Promote Excellence and I...
# Scraping [9/219]: Establishing the United States Investment Accelera...
# Scraping [10/219]: Ensuring Commercial, Cost-Effective Solutions in F...
# Scraping [11/219]: Ensuring National Security and Economic Resilience...
# Scraping [12/219]: Preventing Woke AI in the Federal Government...
# Scraping [13/219]: Promoting the Export of the American AI Technology...
# Scraping [14/219]: Ending Crime and Disorder on America's Streets...
# Scraping [15/219]: Providing for the Revocation of Syria Sanctions...
# Scraping [16/219]: Establishing the President's Make America Beautifu...
# Scraping [17/219]: Making America Beautiful Again by Improving Our Na...
# Scraping [18/219]: Revocation of Executive Order on Competition...
# Scraping [19/219]: Establishing the White House Task Force on the 202...
# Scraping [20/219]: Amendment to Duties To Address the Flow of Illicit...
# Scraping [21/219]: Further Modifying the Reciprocal Tariff Rates...
# Scraping [22/219]: President's Council on Sports, Fitness, and Nutrit...
# Scraping [23/219]: Enabling Competition in the Commercial Space Indus...
# Scraping [24/219]: Putting America First in International Environment...
# Scraping [25/219]: Restoring the Death Penalty and Protecting Public ...
# Scraping [26/219]: Securing Our Borders...
# Scraping [27/219]: Clarifying the Military's Role in Protecting the T...
# Scraping [28/219]: Defending Women From Gender Ideology Extremism and...
# Scraping [29/219]: Ending Radical Indoctrination in K-12 Schooling...
# Scraping [30/219]: Expanding Educational Freedom and Opportunity for ...
# Scraping [31/219]: Ending Illegal Discrimination and Restoring Merit-...
# Scraping [32/219]: Revocation of Certain Executive Orders...
# Scraping [33/219]: President's Council of Advisors on Science and Tec...
# Scraping [34/219]: Removing Barriers to American Leadership in Artifi...
# Scraping [35/219]: Restoring Freedom of Speech and Ending Federal Cen...
# Scraping [135/219]: Amendment to Duties To Address the Flow of Illicit...
# Scraping [136/219]: Amendment to Duties To Address the Situation at Ou...
# Scraping [137/219]: Ensuring Lawful Governance and Implementing the Pr...
# Scraping [138/219]: Progress on the Situation at Our Northern Border...
# Scraping [139/219]: Withdrawing the United States From and Ending Fund...
# Scraping [140/219]: Imposing Duties To Address the Flow of Illicit Dru...
# Scraping [141/219]: Imposing Duties To Address the Situation at Our So...
# Scraping [142/219]: Keeping Education Accessible and Ending COVID-19 V...
# Scraping [143/219]: Ending Taxpayer Subsidization of Biased Media...
# Scraping [144/219]: Establishment of the Religious Liberty Commission...
# Scraping [145/219]: Increasing Efficiency at the Office of the Federal...
# Scraping [146/219]: Keeping Promises to Veterans and Establishing a Na...
# Scraping [147/219]: Prioritizing Military Excellence and Readiness...
# Scraping [148/219]: Reinstating Service Members Discharged Under the M...
# Scraping [149/219]: Restoring America's Fighting Force...
# Scraping [150/219]: The Iron Dome for America...
# Scraping [151/219]: Protecting Children From Chemical and Surgical Mut...
# Scraping [152/219]: Additional Measures To Combat Anti-Semitism...
# Scraping [153/219]: Celebrating America's 250th Birthday...
# Scraping [154/219]: Restoring Accountability to Policy-Influencing Pos...
# Scraping [155/219]: Restoring Names That Honor American Greatness...
# Scraping [156/219]: Designation of Ansar Allah as a Foreign Terrorist ...
# Scraping [157/219]: Declassification of Records Concerning the Assassi...
# Scraping [158/219]: Strengthening American Leadership in Digital Finan...
# Scraping [159/219]: Council To Assess the Federal Emergency Management...
# Scraping [160/219]: Emergency Measures To Provide Water Resources in C...
# Scraping [161/219]: Enforcing the Hyde Amendment...
# Scraping [162/219]: Establishment of the White House Faith Office...
# Scraping [163/219]: Protecting Second Amendment Rights...
# Scraping [164/219]: Unleashing Prosperity Through Deregulation...
# Scraping [165/219]: Application of Protecting Americans From Foreign A...
# Scraping [166/219]: Reevaluating and Realigning United States Foreign ...
# Scraping [167/219]: Ending the Weaponization of the Federal Government...
# Scraping [168/219]: Initial Rescissions of Harmful Executive Orders an...
# Scraping [169/219]: Creating Schedule G in the Excepted Service...
# Scraping [170/219]: America First Policy Directive to the Secretary of...
# Scraping [171/219]: Holding Former Government Officials Accountable fo...
# Scraping [172/219]: Unleashing American Energy...
# Scraping [173/219]: Withdrawing the United States From the World Healt...
# Scraping [174/219]: Designating Cartels and Other Organizations as For...
# Scraping [175/219]: Establishing and Implementing the President's "Dep...
# Scraping [176/219]: Protecting the American People Against Invasion...
# Scraping [177/219]: Establishing an Emergency Board To Investigate Dis...
# Scraping [178/219]: Further Extending the TikTok Enforcement Delay...
# Scraping [179/219]: The Gold Card...
# Scraping [180/219]: Accelerating Federal Permitting of Data Center Inf...
# Scraping [181/219]: Saving College Sports...
# Scraping [182/219]: Addressing Threats to the United States by the Gov...
# Scraping [183/219]: Democratizing Access to Alternative Assets for 401...
# Scraping [184/219]: Guaranteeing Fair Banking for All Americans...
# Scraping [185/219]: Improving Oversight of Federal Grantmaking...
# Scraping [186/219]: Ensuring American Pharmaceutical Supply Chain Resi...
# Scraping [187/219]: Leading the World in Supersonic Flight...
# Scraping [188/219]: Sustaining Select Efforts To Strengthen the Nation...
# Scraping [189/219]: Unleashing American Drone Dominance...
# Scraping [190/219]: Further Exclusions From the Federal Labor- Managem...
# Scraping [191/219]: Making Federal Architecture Beautiful Again...
# Scraping [192/219]: Additional Measures To Address the Crime Emergency...
# Scraping [193/219]: Taking Steps To End Cashless Bail To Protect Ameri...
# Scraping [194/219]: Declaring a Crime Emergency in the District of Col...
# Scraping [195/219]: Making America Healthy Again by Empowering Patient...
# Scraping [196/219]: Implementing the President's "Department of Govern...
# Scraping [197/219]: Protecting America's Bank Account Against Fraud, W...
# Scraping [198/219]: Immediate Measures To Increase American Mineral Pr...
# Scraping [199/219]: Further Amendment to Duties Addressing the Synthet...
# Scraping [200/219]: Addressing Risks From WilmerHale...
# Scraping [201/219]: Exclusions From Federal Labor-Management Relations...
# Scraping [202/219]: Making the District of Columbia Safe and Beautiful...
# Scraping [203/219]: Restoring Truth and Sanity to American History...
# Scraping [204/219]: Combating Unfair Practices in the Live Entertainme...
# Scraping [205/219]: Establishing a White House Office for Special Peac...
# Error scraping https://www.federalregister.gov/documents/2025/07/03/2025-12505/establishing-a-white-house-office-for-special-peace-missions: 500 Server Error: Internal Server Error for url: https://www.federalregister.gov/documents/2025/07/03/2025-12505/establishing-a-white-house-office-for-special-peace-missions
#   -> No text found.
# Scraping [206/219]: Ending Market Distorting Subsidies for Unreliable,...
# Scraping [207/219]: Reforming the Federal Hiring Process and Restoring...
# Scraping [208/219]: Implementing the President's "Department of Govern...
# Scraping [209/219]: Protecting the United States From Foreign Terroris...
# Scraping [210/219]: Suspending Duty-Free De Minimis Treatment for All ...
# Scraping [211/219]: Assuring the Security of the State of Qatar...
# Scraping [212/219]: Unlocking Cures for Pediatric Cancer With Artifici...
# Scraping [213/219]: Modifying Duties Addressing the Synthetic Opioid S...
# Scraping [214/219]: Modifying Reciprocal Tariff Rates Consistent With ...
# Scraping [215/219]: Modifying the Scope of Reciprocal Tariffs and Esta...
# Scraping [216/219]: Modifying the Scope of the Reciprocal Tariffs With...
# Scraping [217/219]: Modifying the Scope of Tariffs on the Government o...
# Scraping [218/219]: Addressing Threats to the United States by the Gov...
# Scraping [219/219]: Saving TikTok While Protecting National Security...

# %%
output_file = "orders.json"

with open(output_file, 'w', encoding='utf-8') as f:
    json.dump(orders_data, f, ensure_ascii=False, indent=2)
    
print(f"Saved {len(orders_data)} orders to {output_file}")
# Out:
# Saved 218 orders to orders.json

# %%
# Verify the output
if orders_data:
    print("First order snippet:")
    print(orders_data[0].get('full_text', '')[:500])
else:
    print("No data to verify.")
# Out:
# First order snippet:
# (
#
# printed page 43895)
#
# Executive Order 14348
#
# of September 5, 2025
#
# Strengthening Efforts To Protect U.S. Nationals From Wrongful Detention Abroad
#
# By the authority vested in me as President by the Constitution and the laws of the United States of America, including the Robert Levinson Hostage Recovery and Hostage-Taking Accountability Act (
#
# 22 U.S.C. 1741
#
# et seq.
#
# ) (Levinson Act), it is hereby ordered:
#
# Section 1
#
# .
#
# Purpose.
#
# The United States must strengthen efforts to protect U.S. nation
